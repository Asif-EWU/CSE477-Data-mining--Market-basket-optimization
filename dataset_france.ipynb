# %%
# %run dataset_1.ipynb
pd.set_option('display.max_colwidth', 199)
pd.set_option('display.max_rows', 100)  # or 1000

# %%
data_france = (clean_data[clean_data['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack())
data_france.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  NaN                 NaN
# 536852                                  NaN                 NaN
# 536974                                  NaN                 NaN
# 537065                                  NaN                 NaN
# 537463                                  NaN                 NaN
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                NaN                       NaN
# 536852                                NaN                       NaN
# 536974                                NaN                       NaN
# 537065                                NaN                       NaN
# 537463                                NaN                       NaN
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# ...

# %%
basket_france = data_france.applymap(lambda x: True if x > 0 else False)
basket_france.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                False               False
# 536852                                False               False
# 536974                                False               False
# 537065                                False               False
# 537463                                False               False
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                              False                     False
# 536852                              False                     False
# 536974                              False                     False
# 537065                              False                     False
# 537463                              False                     False
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# ...

# %%
freq_itemset_france= apriori(basket_france, min_support=0.02, use_colnames=True)
freq_itemset_france['length'] = freq_itemset_france['itemsets'].apply(lambda x: len(x))
freq_itemset_france
# Out:
#        support  \
# 0     0.023560
# 1     0.041885
# 2     0.031414
# 3     0.023560
# 4     0.036649
# ...        ...
# 1551  0.020942
# 1552  0.031414
# 1553  0.023560
# 1554  0.031414
# 1555  0.028796
#
#                                                                                                                                                                                          itemsets  \
# 0                                                                                                                                                                            ( DOLLY GIRL BEAKER)
# 1                                                                                                                                                                       ( SPACEBOY BABY GIFT SET)
# 2                                                                                                                                                                        (10 COLOUR SPACEBOY PEN)
# ...

# %%
rules_france = association_rules(freq_itemset_france, metric="confidence", min_threshold=0.9)
rules_france
# Out:
#                                                                                                                             antecedents  \
# 0                                                                                                            (DOLLY GIRL BABY GIFT SET)
# 1                                                                                                                    (CARD DOLLY GIRL )
# 2                                                                                                         (CHILDRENS CUTLERY SPACEBOY )
# 3                                                                                                    (CHILDS BREAKFAST SET DOLLY GIRL )
# 4                                                                                                            (DOLLY GIRL CHILDRENS CUP)
# ..                                                                                                                                  ...
# ...
