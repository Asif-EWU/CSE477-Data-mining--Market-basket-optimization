# %%
# %run dataset_1.ipynb
pd.set_option('display.max_colwidth', 199)
pd.set_option('display.max_rows', 100)  # or 1000

# %%
data_germany = (clean_data[clean_data['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack())
data_germany.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                  NaN                 NaN
# 536840                                  NaN                 NaN
# 536861                                  NaN                 NaN
# 536967                                  NaN                 NaN
# 536983                                  NaN                 NaN
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                                NaN                       NaN
# 536840                                NaN                       NaN
# 536861                                NaN                       NaN
# 536967                                NaN                       NaN
# 536983                                NaN                       NaN
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# ...

# %%
basket_germany = data_germany.applymap(lambda x: True if x > 0 else False)
basket_germany.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                False               False
# 536840                                False               False
# 536861                                False               False
# 536967                                False               False
# 536983                                False               False
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                              False                     False
# 536840                              False                     False
# 536861                              False                     False
# 536967                              False                     False
# 536983                              False                     False
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# ...

# %%
freq_itemset_germany= apriori(basket_germany, min_support=0.01, use_colnames=True)
freq_itemset_germany['length'] = freq_itemset_germany['itemsets'].apply(lambda x: len(x))
freq_itemset_germany
# Out:
#        support  \
# 0     0.011287
# 1     0.015801
# 2     0.011287
# 3     0.011287
# 4     0.024831
# ...        ...
# 3964  0.011287
# 3965  0.011287
# 3966  0.011287
# 3967  0.011287
# 3968  0.011287
#
#                                                                                                                                                                                                     itemsets  \
# 0                                                                                                                                                                           ( 50'S CHRISTMAS GIFT BAG LARGE)
# 1                                                                                                                                                                                       ( DOLLY GIRL BEAKER)
# ...

# %%
rules_germany = association_rules(freq_itemset_germany, metric="confidence", min_threshold=0.83)
rules_germany
# Out:
#                                                                                                      antecedents  \
# 0                                                                                           ( DOLLY GIRL BEAKER)
# 1                                                                                        (BRIGHT BLUES RIBBONS )
# 2                                                                              (60 CAKE CASES DOLLY GIRL DESIGN)
# 3                                                                                  (PINK HAPPY BIRTHDAY BUNTING)
# 4                                                                                          (PINK POLKADOT WRAP )
# ...                                                                                                          ...
# 2634          (BLUE SPOT CERAMIC DRAWER KNOB, ROUND SNACK BOXES SET OF4 WOODLAND , RED SPOT CERAMIC DRAWER KNOB)
# ...
