# %%
# %run dataset_1.ipynb
pd.set_option('display.max_colwidth', 199)
pd.set_option('display.max_rows', 100)  # or 1000

# %%
data_uk = (clean_data[clean_data['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack())
data_uk.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  NaN                             NaN
# 536366                                  NaN                             NaN
# 536367                                  NaN                             NaN
# 536368                                  NaN                             NaN
# 536369                                  NaN                             NaN
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                      NaN                           NaN
# 536366                      NaN                           NaN
# 536367                      NaN                           NaN
# 536368                      NaN                           NaN
# 536369                      NaN                           NaN
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# ...

# %%
basket_uk = data_uk.applymap(lambda x: True if x > 0 else False)
basket_uk.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                False                           False
# 536366                                False                           False
# 536367                                False                           False
# 536368                                False                           False
# 536369                                False                           False
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                    False                         False
# 536366                    False                         False
# 536367                    False                         False
# 536368                    False                         False
# 536369                    False                         False
#
# Description   NINE DRAWER OFFICE TIDY   OVAL WALL MIRROR DIAMANTE   \
# InvoiceNo
# ...

# %%
freq_itemset_uk= apriori(basket_uk, min_support=0.016, use_colnames=True)
freq_itemset_uk['length'] = freq_itemset_uk['itemsets'].apply(lambda x: len(x))
freq_itemset_uk
# Out:
#       support  \
# 0    0.018266
# 1    0.018936
# 2    0.018825
# 3    0.016646
# 4    0.020277
# ..        ...
# 643  0.016646
# 644  0.017428
# 645  0.016590
# 646  0.016255
# 647  0.017037
#
#                                                                                          itemsets  \
# 0                                                                 (12 PENCIL SMALL TUBE WOODLAND)
# 1                                                           (12 PENCILS SMALL TUBE RED RETROSPOT)
# 2                                                                   (12 PENCILS SMALL TUBE SKULL)
# 3                                                            (3 HEARTS HANGING DECORATION RUSTIC)
# 4                                                              (3 HOOK PHOTO SHELF ANTIQUE WHITE)
# ..                                                                                            ...
# 643                (LUNCH BAG SPACEBOY DESIGN , LUNCH BAG RED RETROSPOT, LUNCH BAG  BLACK SKULL.)
# ...

# %%
rules_uk = association_rules(freq_itemset_uk, metric="confidence", min_threshold=0.3)
rules_uk
# Out:
#                                                antecedents  \
# 0                     (PACK OF 60 PINK PAISLEY CAKE CASES)
# 1                            (60 TEATIME FAIRY CAKE CASES)
# 2                        (PACK OF 72 RETROSPOT CAKE CASES)
# 3                            (60 TEATIME FAIRY CAKE CASES)
# 4                             (ALARM CLOCK BAKELIKE GREEN)
# ..                                                     ...
# 382  (RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOTTE BAG)
# 383     (WOODLAND CHARLOTTE BAG, STRAWBERRY CHARLOTTE BAG)
# 384                          (RED RETROSPOT CHARLOTTE BAG)
# 385                             (STRAWBERRY CHARLOTTE BAG)
# 386                               (WOODLAND CHARLOTTE BAG)
#
#                                                  consequents  \
# 0                              (60 TEATIME FAIRY CAKE CASES)
# 1                       (PACK OF 60 PINK PAISLEY CAKE CASES)
# 2                              (60 TEATIME FAIRY CAKE CASES)
# ...
