# %%
# %run dataset_1.ipynb
pd.set_option('display.max_colwidth', 199)
pd.set_option('display.max_rows', 100)  # or 1000

# %%
data_ireland = (clean_data[clean_data['Country'] =="EIRE"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack())
data_ireland.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536540                                  NaN                             NaN
# 536541                                  NaN                             NaN
# 536803                                  NaN                             NaN
# 536885                                  NaN                             NaN
# 536890                                  NaN                             NaN
#
# Description   DOLLY GIRL BEAKER   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536540                      NaN                       NaN
# 536541                      NaN                       NaN
# 536803                      NaN                       NaN
# 536885                      NaN                       NaN
# 536890                      NaN                       NaN
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# ...

# %%
basket_ireland = data_ireland.applymap(lambda x: True if x > 0 else False)
basket_ireland.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536540                                False                           False
# 536541                                False                           False
# 536803                                False                           False
# 536885                                False                           False
# 536890                                False                           False
#
# Description   DOLLY GIRL BEAKER   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536540                    False                     False
# 536541                    False                     False
# 536803                    False                     False
# 536885                    False                     False
# 536890                    False                     False
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# ...

# %%
freq_itemset_ireland= apriori(basket_ireland, min_support=0.03, use_colnames=True)
freq_itemset_ireland['length'] = freq_itemset_ireland['itemsets'].apply(lambda x: len(x))
freq_itemset_ireland
# Out:
#       support  \
# 0    0.049645
# 1    0.035461
# 2    0.035461
# 3    0.035461
# 4    0.060284
# ..        ...
# 814  0.031915
# 815  0.039007
# 816  0.031915
# 817  0.031915
# 818  0.031915
#
#                                                                                                                                                                                                    itemsets  \
# 0                                                                                                                                                                     (15CM CHRISTMAS GLASS BALL 20 LIGHTS)
# 1                                                                                                                                                                                 (20 DOLLY PEGS RETROSPOT)
# ...

# %%
rules_ireland = association_rules(freq_itemset_ireland, metric="confidence", min_threshold=1)
rules_ireland
# Out:
#                                                                                                                                                           antecedents  \
# 0                                                                                                                                        (BAKING SET SPACEBOY DESIGN)
# 1                                                                                                           (REGENCY TEA PLATE PINK, GREEN REGENCY TEACUP AND SAUCER)
# 2                                                                                                         (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACUP AND SAUCER)
# 3                                                                                                         (REGENCY SUGAR BOWL GREEN, GREEN REGENCY TEACUP AND SAUCER)
# ...
